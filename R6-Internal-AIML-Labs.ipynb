# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
from google.colab import drive
drive.mount(('/content/drive'))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X = iris_data.data
y = iris_data.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=3)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
y_train.shape
# Out:
# (112, 3)

# %%
#model.add(tf.keras.layers.Reshape((4,),input_shape=(4,)))

model.add(tf.keras.layers.Dense(3, activation='softmax', input_shape=(4,)))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)
# Out:
# Train on 112 samples, validate on 38 samples
# Epoch 1/100
# 112/112 [==============================] - 1s 7ms/sample - loss: 2.6538 - accuracy: 0.3393 - val_loss: 1.8389 - val_accuracy: 0.3158
# Epoch 2/100
# 112/112 [==============================] - 0s 211us/sample - loss: 1.6159 - accuracy: 0.3036 - val_loss: 1.4069 - val_accuracy: 0.1842
# Epoch 3/100
# 112/112 [==============================] - 0s 171us/sample - loss: 1.3305 - accuracy: 0.0804 - val_loss: 1.2803 - val_accuracy: 0.1579
# Epoch 4/100
# 112/112 [==============================] - 0s 204us/sample - loss: 1.2189 - accuracy: 0.1964 - val_loss: 1.2168 - val_accuracy: 0.2368
# Epoch 5/100
# 112/112 [==============================] - 0s 192us/sample - loss: 1.1628 - accuracy: 0.2143 - val_loss: 1.1757 - val_accuracy: 0.1842
# Epoch 6/100
# 112/112 [==============================] - 0s 170us/sample - loss: 1.1205 - accuracy: 0.2768 - val_loss: 1.1424 - val_accuracy: 0.2105
# Epoch 7/100
# 112/112 [==============================] - 0s 175us/sample - loss: 1.0855 - accuracy: 0.2857 - val_loss: 1.1131 - val_accuracy: 0.2105
# Epoch 8/100
# 112/112 [==============================] - 0s 190us/sample - loss: 1.0570 - accuracy: 0.2768 - val_loss: 1.0876 - val_accuracy: 0.1579
# Epoch 9/100
# 112/112 [==============================] - 0s 216us/sample - loss: 1.0246 - accuracy: 0.2768 - val_loss: 1.0654 - val_accuracy: 0.1316
# Epoch 10/100
# 112/112 [==============================] - 0s 210us/sample - loss: 0.9950 - accuracy: 0.2768 - val_loss: 1.0357 - val_accuracy: 0.2105
# Epoch 11/100
# 112/112 [==============================] - 0s 198us/sample - loss: 0.9642 - accuracy: 0.3125 - val_loss: 1.0079 - val_accuracy: 0.2368
# Epoch 12/100
# 112/112 [==============================] - 0s 202us/sample - loss: 0.9471 - accuracy: 0.2946 - val_loss: 0.9874 - val_accuracy: 0.4211
# Epoch 13/100
# 112/112 [==============================] - 0s 199us/sample - loss: 0.9194 - accuracy: 0.5625 - val_loss: 0.9671 - val_accuracy: 0.3947
# Epoch 14/100
# 112/112 [==============================] - 0s 219us/sample - loss: 0.9002 - accuracy: 0.6071 - val_loss: 0.9435 - val_accuracy: 0.4211
# Epoch 15/100
# 112/112 [==============================] - 0s 207us/sample - loss: 0.8731 - accuracy: 0.6429 - val_loss: 0.9264 - val_accuracy: 0.3947
# Epoch 16/100
# 112/112 [==============================] - 0s 211us/sample - loss: 0.8536 - accuracy: 0.6518 - val_loss: 0.9100 - val_accuracy: 0.3947
# Epoch 17/100
# 112/112 [==============================] - 0s 277us/sample - loss: 0.8383 - accuracy: 0.6339 - val_loss: 0.8933 - val_accuracy: 0.4474
# Epoch 18/100
# 112/112 [==============================] - 0s 202us/sample - loss: 0.8232 - accuracy: 0.6696 - val_loss: 0.8768 - val_accuracy: 0.5000
# Epoch 19/100
# 112/112 [==============================] - 0s 203us/sample - loss: 0.8034 - accuracy: 0.6696 - val_loss: 0.8627 - val_accuracy: 0.4474
# Epoch 20/100
# 112/112 [==============================] - 0s 189us/sample - loss: 0.7907 - accuracy: 0.6964 - val_loss: 0.8485 - val_accuracy: 0.4737
# Epoch 21/100
# 112/112 [==============================] - 0s 172us/sample - loss: 0.7775 - accuracy: 0.6875 - val_loss: 0.8344 - val_accuracy: 0.5263
# Epoch 22/100
# 112/112 [==============================] - 0s 203us/sample - loss: 0.7604 - accuracy: 0.6964 - val_loss: 0.8229 - val_accuracy: 0.5263
# Epoch 23/100
# 112/112 [==============================] - 0s 234us/sample - loss: 0.7533 - accuracy: 0.6964 - val_loss: 0.8108 - val_accuracy: 0.5789
# Epoch 24/100
# 112/112 [==============================] - 0s 216us/sample - loss: 0.7424 - accuracy: 0.7321 - val_loss: 0.8000 - val_accuracy: 0.5526
# Epoch 25/100
# 112/112 [==============================] - 0s 198us/sample - loss: 0.7306 - accuracy: 0.6875 - val_loss: 0.7894 - val_accuracy: 0.5789
# Epoch 26/100
# 112/112 [==============================] - 0s 195us/sample - loss: 0.7171 - accuracy: 0.6964 - val_loss: 0.7793 - val_accuracy: 0.5789
# Epoch 27/100
# 112/112 [==============================] - 0s 180us/sample - loss: 0.7098 - accuracy: 0.7232 - val_loss: 0.7696 - val_accuracy: 0.5789
# Epoch 28/100
# 112/112 [==============================] - 0s 191us/sample - loss: 0.6962 - accuracy: 0.7589 - val_loss: 0.7639 - val_accuracy: 0.5526
# Epoch 29/100
# 112/112 [==============================] - 0s 262us/sample - loss: 0.6877 - accuracy: 0.7143 - val_loss: 0.7559 - val_accuracy: 0.5263
# Epoch 30/100
# 112/112 [==============================] - 0s 178us/sample - loss: 0.6766 - accuracy: 0.6964 - val_loss: 0.7476 - val_accuracy: 0.5263
# Epoch 31/100
# 112/112 [==============================] - 0s 185us/sample - loss: 0.6695 - accuracy: 0.7232 - val_loss: 0.7401 - val_accuracy: 0.5263
# Epoch 32/100
# 112/112 [==============================] - 0s 167us/sample - loss: 0.6610 - accuracy: 0.7411 - val_loss: 0.7292 - val_accuracy: 0.6316
# Epoch 33/100
# 112/112 [==============================] - 0s 177us/sample - loss: 0.6566 - accuracy: 0.7321 - val_loss: 0.7209 - val_accuracy: 0.6316
# Epoch 34/100
# 112/112 [==============================] - 0s 172us/sample - loss: 0.6499 - accuracy: 0.7143 - val_loss: 0.7146 - val_accuracy: 0.6316
# Epoch 35/100
# 112/112 [==============================] - 0s 174us/sample - loss: 0.6407 - accuracy: 0.7411 - val_loss: 0.7079 - val_accuracy: 0.6579
# Epoch 36/100
# 112/112 [==============================] - 0s 171us/sample - loss: 0.6335 - accuracy: 0.7768 - val_loss: 0.7012 - val_accuracy: 0.6316
# Epoch 37/100
# 112/112 [==============================] - 0s 185us/sample - loss: 0.6267 - accuracy: 0.7857 - val_loss: 0.6990 - val_accuracy: 0.5789
# Epoch 38/100
# 112/112 [==============================] - 0s 170us/sample - loss: 0.6196 - accuracy: 0.7411 - val_loss: 0.6922 - val_accuracy: 0.6053
# Epoch 39/100
# 112/112 [==============================] - 0s 200us/sample - loss: 0.6141 - accuracy: 0.7589 - val_loss: 0.6852 - val_accuracy: 0.6579
# Epoch 40/100
# 112/112 [==============================] - 0s 219us/sample - loss: 0.6114 - accuracy: 0.7321 - val_loss: 0.6782 - val_accuracy: 0.6579
# Epoch 41/100
# 112/112 [==============================] - 0s 186us/sample - loss: 0.6032 - accuracy: 0.7589 - val_loss: 0.6733 - val_accuracy: 0.6579
# Epoch 42/100
# 112/112 [==============================] - 0s 189us/sample - loss: 0.6029 - accuracy: 0.7500 - val_loss: 0.6699 - val_accuracy: 0.6579
# Epoch 43/100
# 112/112 [==============================] - 0s 182us/sample - loss: 0.5992 - accuracy: 0.7679 - val_loss: 0.6687 - val_accuracy: 0.5789
# Epoch 44/100
# 112/112 [==============================] - 0s 184us/sample - loss: 0.5871 - accuracy: 0.7411 - val_loss: 0.6617 - val_accuracy: 0.6053
# Epoch 45/100
# 112/112 [==============================] - 0s 197us/sample - loss: 0.5821 - accuracy: 0.7679 - val_loss: 0.6550 - val_accuracy: 0.6842
# Epoch 46/100
# 112/112 [==============================] - 0s 254us/sample - loss: 0.5809 - accuracy: 0.7679 - val_loss: 0.6549 - val_accuracy: 0.6053
# Epoch 47/100
# 112/112 [==============================] - 0s 230us/sample - loss: 0.5746 - accuracy: 0.7321 - val_loss: 0.6453 - val_accuracy: 0.7105
# Epoch 48/100
# 112/112 [==============================] - 0s 222us/sample - loss: 0.5683 - accuracy: 0.8036 - val_loss: 0.6427 - val_accuracy: 0.6579
# Epoch 49/100
# 112/112 [==============================] - 0s 195us/sample - loss: 0.5663 - accuracy: 0.8036 - val_loss: 0.6409 - val_accuracy: 0.6053
# Epoch 50/100
# 112/112 [==============================] - 0s 200us/sample - loss: 0.5667 - accuracy: 0.7589 - val_loss: 0.6371 - val_accuracy: 0.6053
# Epoch 51/100
# 112/112 [==============================] - 0s 234us/sample - loss: 0.5570 - accuracy: 0.7589 - val_loss: 0.6297 - val_accuracy: 0.7105
# Epoch 52/100
# 112/112 [==============================] - 0s 197us/sample - loss: 0.5546 - accuracy: 0.7946 - val_loss: 0.6259 - val_accuracy: 0.7105
# Epoch 53/100
# 112/112 [==============================] - 0s 188us/sample - loss: 0.5559 - accuracy: 0.7768 - val_loss: 0.6214 - val_accuracy: 0.7632
# Epoch 54/100
# 112/112 [==============================] - 0s 174us/sample - loss: 0.5489 - accuracy: 0.8125 - val_loss: 0.6220 - val_accuracy: 0.6579
# Epoch 55/100
# 112/112 [==============================] - 0s 214us/sample - loss: 0.5467 - accuracy: 0.7500 - val_loss: 0.6143 - val_accuracy: 0.7632
# Epoch 56/100
# 112/112 [==============================] - 0s 220us/sample - loss: 0.5453 - accuracy: 0.7857 - val_loss: 0.6127 - val_accuracy: 0.6842
# Epoch 57/100
# 112/112 [==============================] - 0s 212us/sample - loss: 0.5356 - accuracy: 0.7768 - val_loss: 0.6091 - val_accuracy: 0.6842
# Epoch 58/100
# 112/112 [==============================] - 0s 238us/sample - loss: 0.5324 - accuracy: 0.7857 - val_loss: 0.6050 - val_accuracy: 0.7632
# Epoch 59/100
# 112/112 [==============================] - 0s 196us/sample - loss: 0.5313 - accuracy: 0.8214 - val_loss: 0.6097 - val_accuracy: 0.6053
# Epoch 60/100
# 112/112 [==============================] - 0s 210us/sample - loss: 0.5333 - accuracy: 0.7500 - val_loss: 0.5977 - val_accuracy: 0.7632
# Epoch 61/100
# 112/112 [==============================] - 0s 269us/sample - loss: 0.5267 - accuracy: 0.8393 - val_loss: 0.5967 - val_accuracy: 0.7368
# Epoch 62/100
# 112/112 [==============================] - 0s 246us/sample - loss: 0.5210 - accuracy: 0.7768 - val_loss: 0.5916 - val_accuracy: 0.7632
# Epoch 63/100
# 112/112 [==============================] - 0s 222us/sample - loss: 0.5201 - accuracy: 0.8125 - val_loss: 0.5883 - val_accuracy: 0.7368
# Epoch 64/100
# 112/112 [==============================] - 0s 207us/sample - loss: 0.5172 - accuracy: 0.8482 - val_loss: 0.5879 - val_accuracy: 0.7632
# Epoch 65/100
# 112/112 [==============================] - 0s 191us/sample - loss: 0.5122 - accuracy: 0.7768 - val_loss: 0.5847 - val_accuracy: 0.7632
# Epoch 66/100
# 112/112 [==============================] - 0s 190us/sample - loss: 0.5102 - accuracy: 0.8125 - val_loss: 0.5815 - val_accuracy: 0.7632
# Epoch 67/100
# 112/112 [==============================] - 0s 193us/sample - loss: 0.5109 - accuracy: 0.7946 - val_loss: 0.5776 - val_accuracy: 0.7368
# Epoch 68/100
# 112/112 [==============================] - 0s 187us/sample - loss: 0.5067 - accuracy: 0.8304 - val_loss: 0.5756 - val_accuracy: 0.7632
# Epoch 69/100
# 112/112 [==============================] - 0s 197us/sample - loss: 0.5067 - accuracy: 0.8214 - val_loss: 0.5748 - val_accuracy: 0.7632
# Epoch 70/100
# 112/112 [==============================] - 0s 191us/sample - loss: 0.5004 - accuracy: 0.7857 - val_loss: 0.5716 - val_accuracy: 0.7632
# Epoch 71/100
# 112/112 [==============================] - 0s 193us/sample - loss: 0.4995 - accuracy: 0.8304 - val_loss: 0.5728 - val_accuracy: 0.6842
# Epoch 72/100
# 112/112 [==============================] - 0s 193us/sample - loss: 0.4955 - accuracy: 0.7946 - val_loss: 0.5698 - val_accuracy: 0.7368
# Epoch 73/100
# 112/112 [==============================] - 0s 200us/sample - loss: 0.4944 - accuracy: 0.7857 - val_loss: 0.5656 - val_accuracy: 0.7632
# Epoch 74/100
# 112/112 [==============================] - 0s 193us/sample - loss: 0.4966 - accuracy: 0.7857 - val_loss: 0.5625 - val_accuracy: 0.7632
# Epoch 75/100
# 112/112 [==============================] - 0s 194us/sample - loss: 0.4899 - accuracy: 0.8036 - val_loss: 0.5594 - val_accuracy: 0.7632
# Epoch 76/100
# 112/112 [==============================] - 0s 183us/sample - loss: 0.4872 - accuracy: 0.8661 - val_loss: 0.5609 - val_accuracy: 0.7368
# Epoch 77/100
# 112/112 [==============================] - 0s 182us/sample - loss: 0.4859 - accuracy: 0.7946 - val_loss: 0.5559 - val_accuracy: 0.7632
# Epoch 78/100
# 112/112 [==============================] - 0s 190us/sample - loss: 0.4841 - accuracy: 0.8304 - val_loss: 0.5576 - val_accuracy: 0.7368
# Epoch 79/100
# 112/112 [==============================] - 0s 193us/sample - loss: 0.4827 - accuracy: 0.7768 - val_loss: 0.5515 - val_accuracy: 0.7632
# Epoch 80/100
# 112/112 [==============================] - 0s 187us/sample - loss: 0.4820 - accuracy: 0.8304 - val_loss: 0.5498 - val_accuracy: 0.7632
# Epoch 81/100
# 112/112 [==============================] - 0s 194us/sample - loss: 0.4816 - accuracy: 0.8036 - val_loss: 0.5491 - val_accuracy: 0.7632
# Epoch 82/100
# 112/112 [==============================] - 0s 218us/sample - loss: 0.4753 - accuracy: 0.8214 - val_loss: 0.5491 - val_accuracy: 0.7368
# Epoch 83/100
# 112/112 [==============================] - 0s 195us/sample - loss: 0.4744 - accuracy: 0.7946 - val_loss: 0.5444 - val_accuracy: 0.7632
# Epoch 84/100
# 112/112 [==============================] - 0s 199us/sample - loss: 0.4715 - accuracy: 0.8304 - val_loss: 0.5415 - val_accuracy: 0.7632
# Epoch 85/100
# 112/112 [==============================] - 0s 188us/sample - loss: 0.4720 - accuracy: 0.8304 - val_loss: 0.5443 - val_accuracy: 0.7368
# Epoch 86/100
# 112/112 [==============================] - 0s 215us/sample - loss: 0.4692 - accuracy: 0.8036 - val_loss: 0.5387 - val_accuracy: 0.7632
# Epoch 87/100
# 112/112 [==============================] - 0s 199us/sample - loss: 0.4687 - accuracy: 0.8393 - val_loss: 0.5434 - val_accuracy: 0.7632
# Epoch 88/100
# 112/112 [==============================] - 0s 207us/sample - loss: 0.4697 - accuracy: 0.8036 - val_loss: 0.5365 - val_accuracy: 0.7632
# Epoch 89/100
# 112/112 [==============================] - 0s 236us/sample - loss: 0.4644 - accuracy: 0.8571 - val_loss: 0.5427 - val_accuracy: 0.7105
# Epoch 90/100
# 112/112 [==============================] - 0s 296us/sample - loss: 0.4637 - accuracy: 0.8036 - val_loss: 0.5388 - val_accuracy: 0.7632
# Epoch 91/100
# 112/112 [==============================] - 0s 207us/sample - loss: 0.4609 - accuracy: 0.8036 - val_loss: 0.5312 - val_accuracy: 0.7632
# Epoch 92/100
# 112/112 [==============================] - 0s 201us/sample - loss: 0.4606 - accuracy: 0.8125 - val_loss: 0.5284 - val_accuracy: 0.7632
# Epoch 93/100
# 112/112 [==============================] - 0s 182us/sample - loss: 0.4582 - accuracy: 0.8571 - val_loss: 0.5281 - val_accuracy: 0.7632
# Epoch 94/100
# 112/112 [==============================] - 0s 189us/sample - loss: 0.4557 - accuracy: 0.8393 - val_loss: 0.5258 - val_accuracy: 0.7632
# Epoch 95/100
# 112/112 [==============================] - 0s 222us/sample - loss: 0.4549 - accuracy: 0.8571 - val_loss: 0.5307 - val_accuracy: 0.7632
# Epoch 96/100
# 112/112 [==============================] - 0s 205us/sample - loss: 0.4535 - accuracy: 0.8036 - val_loss: 0.5221 - val_accuracy: 0.7632
# Epoch 97/100
# 112/112 [==============================] - 0s 236us/sample - loss: 0.4506 - accuracy: 0.8571 - val_loss: 0.5206 - val_accuracy: 0.7632
# Epoch 98/100
# 112/112 [==============================] - 0s 190us/sample - loss: 0.4510 - accuracy: 0.8661 - val_loss: 0.5204 - val_accuracy: 0.7632
# Epoch 99/100
# 112/112 [==============================] - 0s 216us/sample - loss: 0.4516 - accuracy: 0.8482 - val_loss: 0.5169 - val_accuracy: 0.7895
# Epoch 100/100
# 112/112 [==============================] - 0s 216us/sample - loss: 0.4472 - accuracy: 0.8750 - val_loss: 0.5181 - val_accuracy: 0.7632

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
predicted = model.predict_classes(X_test)

# %%
predicted[3]
# Out:
# 0

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
y_test[3]
# Out:
# array([1., 0., 0.], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()

# %%
import numpy as np
import pandas as pd

prices = pd.read_csv('/content/drive/My Drive/Internal-R6/prices.csv')

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
prices.drop(['date', 'symbol'], axis=1, inplace=True)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
prices = prices[:1000]

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
X = prices.drop('volume', axis=1)
y = prices['volume']

# %%
y = y/1000000

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X = tf.math.l2_normalize(X)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
W = tf.zeros(shape=(4, 1))
b = tf.zeros(shape=(1))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function
def prediction(features, W, b):
    y_pred = tf.add(tf.matmul(features, W), b)
    return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function
def loss(y_actual, y_predicted):
    diff = y_actual - y_predicted
    sqr = tf.square(diff)
    avg = tf.reduce_mean(sqr)
    return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
@tf.function
def train(x, y_actual, w, b, learning_rate=0.01):
    
    # Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        t.watch([w,b])
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    # Update Weights and Bias
    w = w - learning_rate * dw
    b = b - learning_rate * db
    
    return w, b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):    
    W, b = train(X, y, W, b)
    print('Current Training Loss on iteration', i, loss(y, prediction(X, W, b)).numpy())
# Out:
# Current Training Loss on iteration 0 235.09299
# Current Training Loss on iteration 1 234.06102
# Current Training Loss on iteration 2 233.06998
# Current Training Loss on iteration 3 232.11781
# Current Training Loss on iteration 4 231.20381
# Current Training Loss on iteration 5 230.32585
# Current Training Loss on iteration 6 229.48265
# Current Training Loss on iteration 7 228.67297
# Current Training Loss on iteration 8 227.89539
# Current Training Loss on iteration 9 227.14832
# Current Training Loss on iteration 10 226.43114
# Current Training Loss on iteration 11 225.74234
# Current Training Loss on iteration 12 225.0808
# Current Training Loss on iteration 13 224.44553
# Current Training Loss on iteration 14 223.835
# Current Training Loss on iteration 15 223.24931
# Current Training Loss on iteration 16 222.68655
# Current Training Loss on iteration 17 222.14595
# Current Training Loss on iteration 18 221.62688
# Current Training Loss on iteration 19 221.12842
# Current Training Loss on iteration 20 220.6498
# Current Training Loss on iteration 21 220.18993
# Current Training Loss on iteration 22 219.74841
# Current Training Loss on iteration 23 219.32425
# Current Training Loss on iteration 24 218.91705
# Current Training Loss on iteration 25 218.52579
# Current Training Loss on iteration 26 218.15027
# Current Training Loss on iteration 27 217.78957
# Current Training Loss on iteration 28 217.44315
# Current Training Loss on iteration 29 217.11034
# Current Training Loss on iteration 30 216.79077
# Current Training Loss on iteration 31 216.48412
# Current Training Loss on iteration 32 216.18932
# Current Training Loss on iteration 33 215.90611
# Current Training Loss on iteration 34 215.63437
# Current Training Loss on iteration 35 215.37334
# Current Training Loss on iteration 36 215.12263
# Current Training Loss on iteration 37 214.88185
# Current Training Loss on iteration 38 214.65053
# Current Training Loss on iteration 39 214.42859
# Current Training Loss on iteration 40 214.21527
# Current Training Loss on iteration 41 214.01044
# Current Training Loss on iteration 42 213.81369
# Current Training Loss on iteration 43 213.62482
# Current Training Loss on iteration 44 213.44333
# Current Training Loss on iteration 45 213.2691
# Current Training Loss on iteration 46 213.10179
# Current Training Loss on iteration 47 212.94106
# Current Training Loss on iteration 48 212.78687
# Current Training Loss on iteration 49 212.63857
# Current Training Loss on iteration 50 212.4961
# Current Training Loss on iteration 51 212.35948
# Current Training Loss on iteration 52 212.22816
# Current Training Loss on iteration 53 212.10205
# Current Training Loss on iteration 54 211.98093
# Current Training Loss on iteration 55 211.86461
# Current Training Loss on iteration 56 211.75293
# Current Training Loss on iteration 57 211.64558
# Current Training Loss on iteration 58 211.54266
# Current Training Loss on iteration 59 211.44374
# Current Training Loss on iteration 60 211.34874
# Current Training Loss on iteration 61 211.2575
# Current Training Loss on iteration 62 211.16982
# Current Training Loss on iteration 63 211.08572
# Current Training Loss on iteration 64 211.00484
# Current Training Loss on iteration 65 210.92729
# Current Training Loss on iteration 66 210.85278
# Current Training Loss on iteration 67 210.78104
# Current Training Loss on iteration 68 210.71225
# Current Training Loss on iteration 69 210.64633
# Current Training Loss on iteration 70 210.58289
# Current Training Loss on iteration 71 210.52199
# Current Training Loss on iteration 72 210.46347
# Current Training Loss on iteration 73 210.4073
# Current Training Loss on iteration 74 210.3533
# Current Training Loss on iteration 75 210.30153
# Current Training Loss on iteration 76 210.2518
# Current Training Loss on iteration 77 210.204
# Current Training Loss on iteration 78 210.15811
# Current Training Loss on iteration 79 210.1141
# Current Training Loss on iteration 80 210.0717
# Current Training Loss on iteration 81 210.03108
# Current Training Loss on iteration 82 209.99205
# Current Training Loss on iteration 83 209.95453
# Current Training Loss on iteration 84 209.91852
# Current Training Loss on iteration 85 209.88396
# Current Training Loss on iteration 86 209.85075
# Current Training Loss on iteration 87 209.81891
# Current Training Loss on iteration 88 209.78818
# Current Training Loss on iteration 89 209.75874
# Current Training Loss on iteration 90 209.73053
# Current Training Loss on iteration 91 209.70349
# Current Training Loss on iteration 92 209.67744
# Current Training Loss on iteration 93 209.65225
# Current Training Loss on iteration 94 209.62833
# Current Training Loss on iteration 95 209.6052
# Current Training Loss on iteration 96 209.58302
# Current Training Loss on iteration 97 209.56174
# Current Training Loss on iteration 98 209.5413
# Current Training Loss on iteration 99 209.52167

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
W.numpy()
# Out:
# array([[0.05494982],
#        [0.05504923],
#        [0.05439267],
#        [0.05549985]], dtype=float32)

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
b.numpy()
# Out:
# array([4.621736], dtype=float32)
